# %% [markdown]
# # 연습용 -미완성 끄적임

# %%
import pandas as pd
import matplotlib.pyplot as plt 
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
data = pd.read_csv('./도로교통공단_전국_사망교통사고정보(2018).csv',engine='python')
data.head()
# Out:
#     발생년      발생년월일시  발생분 주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수    ...      \
# 0  2018  2018021406   35  주  수     1     1     0     0       0    ...
# 1  2018  2018090205   23  야  일     1     1     0     0       0    ...
# 2  2018  2018121522   35  야  토     1     1     0     0       0    ...
# 3  2018  2018082311   30  주  목     1     1     0     0       0    ...
# 4  2018  2018071600   50  야  월     1     1     0     0       0    ...
#
#   도로형태_대분류      도로형태 가해자_당사자종별_대분류 가해자_당사자종별 피해자_당사자종별_대분류 피해자_당사자종별  \
# 0      단일로     기타단일로           승용차       승용차           보행자       보행자
# 1      교차로  교차로횡단보도내           승용차       승용차           보행자       보행자
# 2      단일로     기타단일로           이륜차       이륜차            없음        없음
# 3      단일로     기타단일로           승합차       승합차            없음        없음
# 4      교차로  교차로횡단보도내           화물차       화물차           보행자       보행자
#
#   발생위치X_UTMK 발생위치Y_UTMK          경도         위도
# 0   950497.0  1954702.0  126.939274  37.590388
# 1   953337.0  1950150.0  126.971732  37.549508
# 2   956967.0  1954807.0  127.012552  37.591659
# 3   958020.0  1959193.0  127.024227  37.631240
# 4   957606.0  1958258.0  127.019590  37.622794
#
# [5 rows x 27 columns]

# %%
data = data.drop(['발생위치X_UTMK','발생위치Y_UTMK'],axis=1)
data.head()
# Out:
#     발생년      발생년월일시  발생분 주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수    ...      \
# 0  2018  2018021406   35  주  수     1     1     0     0       0    ...
# 1  2018  2018090205   23  야  일     1     1     0     0       0    ...
# 2  2018  2018121522   35  야  토     1     1     0     0       0    ...
# 3  2018  2018082311   30  주  목     1     1     0     0       0    ...
# 4  2018  2018071600   50  야  월     1     1     0     0       0    ...
#
#   법규위반_대분류         법규위반 도로형태_대분류      도로형태 가해자_당사자종별_대분류 가해자_당사자종별  \
# 0  운전자법규위반  안전운전 의무 불이행      단일로     기타단일로           승용차       승용차
# 1  운전자법규위반  안전운전 의무 불이행      교차로  교차로횡단보도내           승용차       승용차
# 2  운전자법규위반  안전운전 의무 불이행      단일로     기타단일로           이륜차       이륜차
# 3  운전자법규위반  기타(운전자법규위반)      단일로     기타단일로           승합차       승합차
# 4  운전자법규위반  안전운전 의무 불이행      교차로  교차로횡단보도내           화물차       화물차
#
#   피해자_당사자종별_대분류 피해자_당사자종별          경도         위도
# 0           보행자       보행자  126.939274  37.590388
# 1           보행자       보행자  126.971732  37.549508
# 2            없음        없음  127.012552  37.591659
# 3            없음        없음  127.024227  37.631240
# 4           보행자       보행자  127.019590  37.622794
#
# [5 rows x 25 columns]

# %%
# 각 columns별 levels 확인
print(data['발생년'].unique())
print(data['법규위반_대분류'].unique())
print(data['법규위반'].unique())
print(data['도로형태_대분류'].unique())
print(data['도로형태'].unique())
# Out:
# [2018]
# ['운전자법규위반' '정비불량']
# ['안전운전 의무 불이행' '기타(운전자법규위반)' '신호위반' '과속' '보행자 보호의무 위반' '중앙선 침범' '안전거리 미확보'
#  '차로위반(진로변경 위반)' '교차로 통행방법 위반' '직진 및 우회전차의 통행방해' '부당한 회전' '앞지르기 방법위반'
#  '앞지르기 금지위반' '철길건널목 통과방법위반' '서행 및 일시정지위반' '정비불량 제차의 운전금지위반'
#  '긴급자동차에대한 피양의무 위반']
# ['단일로' '교차로' '기타' '주차장' '불명' '철길건널목']
# ['기타단일로' '교차로횡단보도내' '교차로내' '교차로부근' '기타' '터널안' '주차장' '지하차도(도로)내' '교량위'
#  '고가도로위' '불명' '철길건널목']

# %%
data['피해자수'] = data[['사망자수','사상자수','중상자수','경상자수','부상신고자수']].sum(axis=1)
data.head()
# Out:
#     발생년      발생년월일시  발생분 주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수 ...   \
# 0  2018  2018021406   35  주  수     1     1     0     0       0 ...
# 1  2018  2018090205   23  야  일     1     1     0     0       0 ...
# 2  2018  2018121522   35  야  토     1     1     0     0       0 ...
# 3  2018  2018082311   30  주  목     1     1     0     0       0 ...
# 4  2018  2018071600   50  야  월     1     1     0     0       0 ...
#
#           법규위반 도로형태_대분류      도로형태 가해자_당사자종별_대분류 가해자_당사자종별 피해자_당사자종별_대분류  \
# 0  안전운전 의무 불이행      단일로     기타단일로           승용차       승용차           보행자
# 1  안전운전 의무 불이행      교차로  교차로횡단보도내           승용차       승용차           보행자
# 2  안전운전 의무 불이행      단일로     기타단일로           이륜차       이륜차            없음
# 3  기타(운전자법규위반)      단일로     기타단일로           승합차       승합차            없음
# 4  안전운전 의무 불이행      교차로  교차로횡단보도내           화물차       화물차           보행자
#
#   피해자_당사자종별          경도         위도 피해자수
# 0       보행자  126.939274  37.590388    2
# 1       보행자  126.971732  37.549508    2
# 2        없음  127.012552  37.591659    2
# 3        없음  127.024227  37.631240    2
# 4       보행자  127.019590  37.622794    2
#
# [5 rows x 26 columns]

# %%
a = data.groupby(['발생지시도'])[['피해자수']].sum()
a = a.reset_index()

# %%
a = a.rename(columns = {'발생지시도':'시도'})

# %%
data2 = pd.read_csv('./도시지역_인구현황_시군구__20190731144832.csv',engine='python')
data2 =data2.iloc[3:,0:2]
data2 = data2.set_index('소재지(시군구)별(1)')

# %%
data2 = data2.rename(index = {"서울특별시": "서울",
                     '부산광역시':'부산',
                     '대구광역시':'대구',
                     '인천광역시':'인천',
                     '광주광역시':'광주',
                     '대전광역시':'대전',
                     '울산광역시':'울산',
                      '세종특별자치시':'세종',
                      '경기도':'경기',
                      '강원도':'강원',
                      '충청북도':'충북',
                      '충청남도':'충남',
                      '전라북도':'전북',
                      '전라남도':'전남',
                      '경상북도':'경북',
                      '경상남도':'경남',
                      '제주특별자치도':'제주'
                     })

# %%
data2 = data2.reset_index()

# %%
data2 = data2.rename(columns={'소재지(시군구)별(1)':'시도'})

# %%
a
# Out:
#     시도  피해자수
# 0   강원   572
# 1   경기  2128
# 2   경남   944
# 3   경북  1202
# 4   광주   222
# 5   대구   346
# 6   대전   258
# 7   부산   376
# 8   서울   850
# 9   세종    46
# 10  울산   328
# 11  인천   338
# 12  전남   942
# 13  전북   724
# 14  제주   210
# 15  충남  1100
# 16  충북   806

# %%
data2
# Out:
#     시도      2018
# 0   서울   9765623
# 1   부산   3441453
# 2   대구   2461769
# 3   인천   2954642
# 4   광주   1459336
# 5   대전   1489936
# 6   울산   1155623
# 7   세종    314126
# 8   경기  13077153
# 9   강원   1543052
# 10  충북   1599252
# 11  충남   2126282
# 12  전북   1836832
# 13  전남   1882970
# 14  경북   2676831
# 15  경남   3373988
# 16  제주    667191

# %%
ratio = pd.merge(a,data2, on ="시도", how="inner")

# %%
ratio
# Out:
#     시도  피해자수      2018
# 0   강원   572   1543052
# 1   경기  2128  13077153
# 2   경남   944   3373988
# 3   경북  1202   2676831
# 4   광주   222   1459336
# 5   대구   346   2461769
# 6   대전   258   1489936
# 7   부산   376   3441453
# 8   서울   850   9765623
# 9   세종    46    314126
# 10  울산   328   1155623
# 11  인천   338   2954642
# 12  전남   942   1882970
# 13  전북   724   1836832
# 14  제주   210    667191
# 15  충남  1100   2126282
# 16  충북   806   1599252

# %%
ratio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 16
# Data columns (total 3 columns):
# 시도      17 non-null object
# 피해자수    17 non-null int64
# 2018    17 non-null object
# dtypes: int64(1), object(2)
# memory usage: 544.0+ bytes

# %%
ratio['2018'] = pd.to_numeric(ratio['2018'])

# %%
ratio['비율(%)'] = (ratio['피해자수'] / ratio['2018'])*100

# %%
ratio = ratio.set_index('시도')

# %%
y1 = ratio['피해자수']
y2 = ratio['비율(%)']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(y1, 'g-',marker='s')
ax2.plot(y2, 'b-',marker='o',linestyle='--')

ax1.set_xlabel('시도',fontsize=15)
ax1.set_ylabel('사상자 수', color='g',fontsize=10)
ax2.set_ylabel('도시별 사상자 비율', color='b',fontsize=10)

plt.title('시도 별 교통사고 사상자 수 및 비율',fontsize=18)
plt.rcParams["figure.figsize"] = (13.5,7)
plt.show()


"""
인구수가 높을수록 사상자 수가 높지만,
비율상으로 놓고보면 사상자 수가 많다고 교통사고에 취약한 도시라고는 할 수 없다.
"""
# Out:
# '\n인구수가 높을수록 사상자 수가 높지만,\n비율상으로 놓고보면 사상자 수가 많다고 교통사고에 취약한 도시라고는 할 수 없다.\n'

# %%
b = data.groupby('법규위반')[['피해자수']].sum()

# %%
b = b.reset_index()

# %%
b.head()
# Out:
#                법규위반  피해자수
# 0                과속   704
# 1       교차로 통행방법 위반   202
# 2       기타(운전자법규위반)   114
# 3  긴급자동차에대한 피양의무 위반     2
# 4       보행자 보호의무 위반   290

# %%
x = range(len(b['피해자수']))
x2 = b['법규위반']

b.plot(kind='bar', figsize=(10,6), color='gray')
plt.xticks(x,x2,rotation=90)
plt.show()

# 안전운전 의무 불이행으로 인한 교통사고 피해자 수가 눈에 뛰게 많음.

# %%
data_num = data.groupby('법규위반')[['사망자수','사상자수','중상자수','경상자수','부상신고자수']].sum()
data_num
# Out:
#                   사망자수  사상자수  중상자수  경상자수  부상신고자수
# 법규위반
# 과속                 237   352    52    59       4
# 교차로 통행방법 위반         56   101    19    16      10
# 기타(운전자법규위반)         36    57    10     9       2
# 긴급자동차에대한 피양의무 위반     1     1     0     0       0
# 보행자 보호의무 위반        135   145     5     4       1
# 부당한 회전              18    20     1     1       0
# 서행 및 일시정지위반          5     7     1     0       1
# 신호위반               294   494    88   103       9
# 안전거리 미확보            65   156    24    56      11
# 안전운전 의무 불이행       2594  3628   413   574      47
# 앞지르기 금지위반            5     5     0     0       0
# 앞지르기 방법위반            5     6     1     0       0
# 정비불량 제차의 운전금지위반      2     2     0     0       0
# 중앙선 침범             288   659   178   185       8
# 직진 및 우회전차의 통행방해     26    41     9     5       1
# 차로위반(진로변경 위반)       12    20     5     3       0
# 철길건널목 통과방법위반         2     2     0     0       0

# %%
data_num.loc['행합계'] = data_num.sum(axis=0)
data_num['열합계'] = data_num.sum(axis=1)

# %%
data_num
# Out:
#                   사망자수  사상자수  중상자수  경상자수  부상신고자수    열합계
# 법규위반
# 과속                 237   352    52    59       4    704
# 교차로 통행방법 위반         56   101    19    16      10    202
# 기타(운전자법규위반)         36    57    10     9       2    114
# 긴급자동차에대한 피양의무 위반     1     1     0     0       0      2
# 보행자 보호의무 위반        135   145     5     4       1    290
# 부당한 회전              18    20     1     1       0     40
# 서행 및 일시정지위반          5     7     1     0       1     14
# 신호위반               294   494    88   103       9    988
# 안전거리 미확보            65   156    24    56      11    312
# 안전운전 의무 불이행       2594  3628   413   574      47   7256
# 앞지르기 금지위반            5     5     0     0       0     10
# 앞지르기 방법위반            5     6     1     0       0     12
# 정비불량 제차의 운전금지위반      2     2     0     0       0      4
# 중앙선 침범             288   659   178   185       8   1318
# 직진 및 우회전차의 통행방해     26    41     9     5       1     82
# 차로위반(진로변경 위반)       12    20     5     3       0     40
# 철길건널목 통과방법위반         2     2     0     0       0      4
# 행합계               3781  5696   806  1015      94  11392

# %%
data.head()
# Out:
#     발생년      발생년월일시  발생분 주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수 ...   \
# 0  2018  2018021406   35  주  수     1     1     0     0       0 ...
# 1  2018  2018090205   23  야  일     1     1     0     0       0 ...
# 2  2018  2018121522   35  야  토     1     1     0     0       0 ...
# 3  2018  2018082311   30  주  목     1     1     0     0       0 ...
# 4  2018  2018071600   50  야  월     1     1     0     0       0 ...
#
#           법규위반 도로형태_대분류      도로형태 가해자_당사자종별_대분류 가해자_당사자종별 피해자_당사자종별_대분류  \
# 0  안전운전 의무 불이행      단일로     기타단일로           승용차       승용차           보행자
# 1  안전운전 의무 불이행      교차로  교차로횡단보도내           승용차       승용차           보행자
# 2  안전운전 의무 불이행      단일로     기타단일로           이륜차       이륜차            없음
# 3  기타(운전자법규위반)      단일로     기타단일로           승합차       승합차            없음
# 4  안전운전 의무 불이행      교차로  교차로횡단보도내           화물차       화물차           보행자
#
#   피해자_당사자종별          경도         위도 피해자수
# 0       보행자  126.939274  37.590388    2
# 1       보행자  126.971732  37.549508    2
# 2        없음  127.012552  37.591659    2
# 3        없음  127.024227  37.631240    2
# 4       보행자  127.019590  37.622794    2
#
# [5 rows x 26 columns]

# %%
temp = data[['발생년월일시']]

# %%
temp.head()
# Out:
#        발생년월일시
# 0  2018021406
# 1  2018090205
# 2  2018121522
# 3  2018082311
# 4  2018071600

# %%
temp['발생년월일시'] = temp['발생년월일시'].astype(str)
# Out:
# D:\install\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3657 entries, 0 to 3656
# Data columns (total 1 columns):
# 발생년월일시    3657 non-null object
# dtypes: object(1)
# memory usage: 28.6+ KB

# %%
temp['year'] = temp.발생년월일시.str[0:4]
temp['month'] = temp.발생년월일시.str[4:6]
temp['date'] = temp.발생년월일시.str[6:8]
temp['time'] = temp.발생년월일시.str[8:10]
# Out:
# D:\install\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# D:\install\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\install\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\install\anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
temp.head()
# Out:
#        발생년월일시  year month date time
# 0  2018021406  2018    02   14   06
# 1  2018090205  2018    09   02   05
# 2  2018121522  2018    12   15   22
# 3  2018082311  2018    08   23   11
# 4  2018071600  2018    07   16   00

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3657 entries, 0 to 3656
# Data columns (total 5 columns):
# 발생년월일시    3657 non-null object
# year      3657 non-null object
# month     3657 non-null object
# date      3657 non-null object
# time      3657 non-null object
# dtypes: object(5)
# memory usage: 142.9+ KB

# %%
data.head()
# Out:
#     발생년      발생년월일시  발생분 주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수 ...   \
# 0  2018  2018021406   35  주  수     1     1     0     0       0 ...
# 1  2018  2018090205   23  야  일     1     1     0     0       0 ...
# 2  2018  2018121522   35  야  토     1     1     0     0       0 ...
# 3  2018  2018082311   30  주  목     1     1     0     0       0 ...
# 4  2018  2018071600   50  야  월     1     1     0     0       0 ...
#
#           법규위반 도로형태_대분류      도로형태 가해자_당사자종별_대분류 가해자_당사자종별 피해자_당사자종별_대분류  \
# 0  안전운전 의무 불이행      단일로     기타단일로           승용차       승용차           보행자
# 1  안전운전 의무 불이행      교차로  교차로횡단보도내           승용차       승용차           보행자
# 2  안전운전 의무 불이행      단일로     기타단일로           이륜차       이륜차            없음
# 3  기타(운전자법규위반)      단일로     기타단일로           승합차       승합차            없음
# 4  안전운전 의무 불이행      교차로  교차로횡단보도내           화물차       화물차           보행자
#
#   피해자_당사자종별          경도         위도 피해자수
# 0       보행자  126.939274  37.590388    2
# 1       보행자  126.971732  37.549508    2
# 2        없음  127.012552  37.591659    2
# 3        없음  127.024227  37.631240    2
# 4       보행자  127.019590  37.622794    2
#
# [5 rows x 26 columns]

# %%
temp['발생년월일시'] = temp['발생년월일시'].astype(int)
# Out:
# D:\install\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_new = pd.merge(temp,data, on = "발생년월일시", how="inner")

# %%
data_new.head()
# Out:
#        발생년월일시  year month date time   발생년  발생분 주야 요일  사망자수 ...          법규위반  \
# 0  2018021406  2018    02   14   06  2018   35  주  수     1 ...   안전운전 의무 불이행
# 1  2018021406  2018    02   14   06  2018   45  주  수     1 ...   교차로 통행방법 위반
# 2  2018021406  2018    02   14   06  2018   35  주  수     1 ...   안전운전 의무 불이행
# 3  2018021406  2018    02   14   06  2018   45  주  수     1 ...   교차로 통행방법 위반
# 4  2018090205  2018    09   02   05  2018   23  야  일     1 ...   안전운전 의무 불이행
#
#    도로형태_대분류      도로형태  가해자_당사자종별_대분류 가해자_당사자종별 피해자_당사자종별_대분류 피해자_당사자종별  \
# 0       단일로     기타단일로            승용차       승용차           보행자       보행자
# 1       교차로      교차로내            승용차       승용차           승용차       승용차
# 2       단일로     기타단일로            승용차       승용차           보행자       보행자
# 3       교차로      교차로내            승용차       승용차           승용차       승용차
# 4       교차로  교차로횡단보도내            승용차       승용차           보행자       보행자
#
#            경도         위도 피해자수
# 0  126.939274  37.590388    2
# 1  127.089017  37.806251    8
# 2  126.939274  37.590388    2
# 3  127.089017  37.806251    8
# 4  126.971732  37.549508    2
#
# [5 rows x 30 columns]

# %%
data_new = data_new.drop(['발생년','발생분'], axis=1)    # 분 단위까지는 분석하지 않음.

# %%
data_new.head()
# Out:
#        발생년월일시  year month date time 주야 요일  사망자수  사상자수  중상자수 ...          법규위반  \
# 0  2018021406  2018    02   14   06  주  수     1     1     0 ...   안전운전 의무 불이행
# 1  2018021406  2018    02   14   06  주  수     1     4     0 ...   교차로 통행방법 위반
# 2  2018021406  2018    02   14   06  주  수     1     1     0 ...   안전운전 의무 불이행
# 3  2018021406  2018    02   14   06  주  수     1     4     0 ...   교차로 통행방법 위반
# 4  2018090205  2018    09   02   05  야  일     1     1     0 ...   안전운전 의무 불이행
#
#    도로형태_대분류      도로형태 가해자_당사자종별_대분류 가해자_당사자종별 피해자_당사자종별_대분류 피해자_당사자종별  \
# 0       단일로     기타단일로           승용차       승용차           보행자       보행자
# 1       교차로      교차로내           승용차       승용차           승용차       승용차
# 2       단일로     기타단일로           승용차       승용차           보행자       보행자
# 3       교차로      교차로내           승용차       승용차           승용차       승용차
# 4       교차로  교차로횡단보도내           승용차       승용차           보행자       보행자
#
#            경도         위도 피해자수
# 0  126.939274  37.590388    2
# 1  127.089017  37.806251    8
# 2  126.939274  37.590388    2
# 3  127.089017  37.806251    8
# 4  126.971732  37.549508    2
#
# [5 rows x 28 columns]
